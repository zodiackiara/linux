# %%
pwd
# Out:
# '/root/jupyter'

# %%
band="/root/vasp/y2o3/band/vasprun.xml"

import matplotlib.pyplot
from pymatgen.io.vasp.outputs import Vasprun
from pymatgen.electronic_structure.plotter import BSDOSPlotter,\
BSPlotter,BSPlotterProjected,DosPlotter
dos_vasprun=Vasprun(band)
dos_data=dos_vasprun.complete_dos
bs_vasprun=Vasprun(band,parse_projected_eigen=True)
bs_data=bs_vasprun.get_band_structure(line_mode=1)
plt_8=BSDOSPlotter(bs_projection='elements', dos_projection=None)
plt_8.get_plot(bs=bs_data,dos=None)
matplotlib.pyplot.savefig('plt_8.png',format='png')
# Out:
# findfont: Font family ['Times New Roman'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Times New Roman'] not found. Falling back to DejaVu Sans.

# %%
band="/root/vasp/y2o3/band/"

import matplotlib.pyplot
from pymatgen.io.vasp.outputs import Vasprun
from pymatgen.electronic_structure.plotter import BSDOSPlotter,\
BSPlotter,BSPlotterProjected,DosPlotter
dos_vasprun=Vasprun(band)
dos_data=dos_vasprun.complete_dos
bs_vasprun=Vasprun(band,parse_projected_eigen=True)
bs_data=bs_vasprun.get_band_structure(line_mode=1)
plt_8=BSDOSPlotter(bs_projection='elements', dos_projection=None)
plt_8.get_plot(bs=bs_data,dos=None)
matplotlib.pyplot.savefig('plt_8.png',format='png')
